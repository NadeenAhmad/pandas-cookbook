# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


plt.rcParams['figure.figsize'] = (15, 5)
plt.rcParams['font.family'] = 'sans-serif'

# This is necessary to show lots of columns in pandas 0.12. 
# Not necessary in pandas 0.13.
pd.set_option('display.width', 5000) 
pd.set_option('display.max_columns', 60)

# %%
requests = pd.read_csv('C:/Users/victory/Desktop/pandas-cookbook/data/311-service-requests.csv')
# Out:
# C:\Users\victory\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
requests['Incident Zip'].unique()
# Out:
# array([11432.0, 11378.0, 10032.0, 10023.0, 10027.0, 11372.0, 11419.0,
#        11417.0, 10011.0, 11225.0, 11218.0, 10003.0, 10029.0, 10466.0,
#        11219.0, 10025.0, 10310.0, 11236.0, nan, 10033.0, 11216.0, 10016.0,
#        10305.0, 10312.0, 10026.0, 10309.0, 10036.0, 11433.0, 11235.0,
#        11213.0, 11379.0, 11101.0, 10014.0, 11231.0, 11234.0, 10457.0,
#        10459.0, 10465.0, 11207.0, 10002.0, 10034.0, 11233.0, 10453.0,
#        10456.0, 10469.0, 11374.0, 11221.0, 11421.0, 11215.0, 10007.0,
#        10019.0, 11205.0, 11418.0, 11369.0, 11249.0, 10005.0, 10009.0,
#        11211.0, 11412.0, 10458.0, 11229.0, 10065.0, 10030.0, 11222.0,
#        10024.0, 10013.0, 11420.0, 11365.0, 10012.0, 11214.0, 11212.0,
#        10022.0, 11232.0, 11040.0, 11226.0, 10281.0, 11102.0, 11208.0,
#        10001.0, 10472.0, 11414.0, 11223.0, 10040.0, 11220.0, 11373.0,
#        11203.0, 11691.0, 11356.0, 10017.0, 10452.0, 10280.0, 11217.0,
# ...

# %%
na_values = ['NO CLUE', 'N/A', '0']
requests = pd.read_csv('C:/Users/victory/Desktop/pandas-cookbook/data/311-service-requests.csv', na_values=na_values, dtype={'Incident Zip': str})

# %%
requests['Incident Zip'].unique()
# Out:
# array(['11432', '11378', '10032', '10023', '10027', '11372', '11419',
#        '11417', '10011', '11225', '11218', '10003', '10029', '10466',
#        '11219', '10025', '10310', '11236', nan, '10033', '11216', '10016',
#        '10305', '10312', '10026', '10309', '10036', '11433', '11235',
#        '11213', '11379', '11101', '10014', '11231', '11234', '10457',
#        '10459', '10465', '11207', '10002', '10034', '11233', '10453',
#        '10456', '10469', '11374', '11221', '11421', '11215', '10007',
#        '10019', '11205', '11418', '11369', '11249', '10005', '10009',
#        '11211', '11412', '10458', '11229', '10065', '10030', '11222',
#        '10024', '10013', '11420', '11365', '10012', '11214', '11212',
#        '10022', '11232', '11040', '11226', '10281', '11102', '11208',
#        '10001', '10472', '11414', '11223', '10040', '11220', '11373',
#        '11203', '11691', '11356', '10017', '10452', '10280', '11217',
# ...

# %%
rows_with_dashes = requests['Incident Zip'].str.contains('-').fillna(False)
len(requests[rows_with_dashes])
# Out:
# 5

# %%
#get rows that contain dashes
requests[rows_with_dashes]
# Out:
#        Unique Key            Created Date             Closed Date Agency                     Agency Name      Complaint Type         Descriptor Location Type Incident Zip        Incident Address         Street Name Cross Street 1 Cross Street 2 Intersection Street 1 Intersection Street 2 Address Type        City Landmark Facility Type    Status                Due Date Resolution Action Updated Date Community Board      Borough  X Coordinate (State Plane)  Y Coordinate (State Plane) Park Facility Name Park Borough  School Name School Number School Region  School Code School Phone Number School Address  School City School State   School Zip School Not Found  School or Citywide Complaint Vehicle Type Taxi Company Borough Taxi Pick Up Location Bridge Highway Name Bridge Highway Direction Road Ramp Bridge Highway Segment Garage Lot Name Ferry Direction Ferry Terminal Name  Latitude  Longitude Location
# ...

# %%
#zip code with more than five digits
long_zip_codes = requests['Incident Zip'].str.len() > 5
#make sure they are okay
requests['Incident Zip'][long_zip_codes].unique()
# Out:
# array(['77092-2016', '55164-0737', '000000', '11549-3650', '29616-0759',
#        '35209-3114'], dtype=object)

# %%
#they are unique then  truncate 
requests['Incident Zip'] = requests['Incident Zip'].str.slice(0, 5)

# %%
# retrieve all rows with all zeros zip code 

requestsrequests[requests['Incident Zip'] == '00000']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-ff3ec34847c6> in <module>()
#       1 # retrieve all rows with all zeros zip code
#       2
# ----> 3 requestsrequests[requests['Incident Zip'] == '00000']
#
# NameError: name 'requestsrequests' is not defined

# %%
# retrieve all rows with all zeros zip code 
requests[requests['Incident Zip'] == '00000']
# Out:
#        Unique Key            Created Date Closed Date Agency                    Agency Name  Complaint Type        Descriptor Location Type Incident Zip  Incident Address     Street Name Cross Street 1 Cross Street 2 Intersection Street 1 Intersection Street 2 Address Type    City Landmark Facility Type    Status                Due Date Resolution Action Updated Date Community Board      Borough  X Coordinate (State Plane)  Y Coordinate (State Plane) Park Facility Name Park Borough  School Name School Number School Region  School Code School Phone Number School Address  School City School State   School Zip School Not Found  School or Citywide Complaint Vehicle Type Taxi Company Borough Taxi Pick Up Location Bridge Highway Name Bridge Highway Direction Road Ramp Bridge Highway Segment Garage Lot Name Ferry Direction Ferry Terminal Name  Latitude  Longitude Location
# ...

# %%
unique_zips = requests['Incident Zip'].unique()
unique_zips.sort()
unique_zips
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-a216f82ef513> in <module>()
#       1 unique_zips = requests['Incident Zip'].unique()
# ----> 2 unique_zips.sort()
#       3 unique_zips
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %%
unique_zips = requests['Incident Zip'].unique()
#unique_zips.sort()
zips = requests['Incident Zip']
# Let's say the zips starting with '0' and '1' are okay, for now. (this isn't actually true -- 13221 is in Syracuse, and why?)
is_close = zips.str.startswith('0') | zips.str.startswith('1')
# There are a bunch of NaNs, but we're not interested in them right now, so we'll say they're False
is_far = ~(is_close) & zips.notnull()unique_zips
# Out:
# array(['11432', '11378', '10032', '10023', '10027', '11372', '11419',
#        '11417', '10011', '11225', '11218', '10003', '10029', '10466',
#        '11219', '10025', '10310', '11236', nan, '10033', '11216', '10016',
#        '10305', '10312', '10026', '10309', '10036', '11433', '11235',
#        '11213', '11379', '11101', '10014', '11231', '11234', '10457',
#        '10459', '10465', '11207', '10002', '10034', '11233', '10453',
#        '10456', '10469', '11374', '11221', '11421', '11215', '10007',
#        '10019', '11205', '11418', '11369', '11249', '10005', '10009',
#        '11211', '11412', '10458', '11229', '10065', '10030', '11222',
#        '10024', '10013', '11420', '11365', '10012', '11214', '11212',
#        '10022', '11232', '11040', '11226', '10281', '11102', '11208',
#        '10001', '10472', '11414', '11223', '10040', '11220', '11373',
#        '11203', '11691', '11356', '10017', '10452', '10280', '11217',
# ...

# %%
#assuming zip codes starting with 1 or zero are okay 
zips = requests['Incident Zip']
# Let's say the zips starting with '0' and '1' are okay, for now. (this isn't actually true -- 13221 is in Syracuse, and why?)
is_close = zips.str.startswith('0') | zips.str.startswith('1')
# There are a bunch of NaNs, but we're not interested in them right now, so we'll say they're False
is_far = ~(is_close) & zips.notnull()

# %%
zips[is_far]
# Out:
# 12102    77056
# 13450    70711
# 29136    77092
# 30939    55164
# 44008    90010
# 47048    23541
# 57636    92123
# 71001    92123
# 71834    23502
# 80573    61702
# 85821    29616
# 89304    35209
# 94201    41042
# Name: Incident Zip, dtype: object

# %%
requests[is_far][['Incident Zip', 'Descriptor', 'City']].sort('Incident Zip')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-7fa08b44a947> in <module>()
# ----> 1 requests[is_far][['Incident Zip', 'Descriptor', 'City']].sort('Incident Zip')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %%
requests[is_far][['Incident Zip', 'Descriptor', 'City']].('Incident Zip')
# Out:
#   File "<ipython-input-17-c47b2c85da41>", line 1
#     requests[is_far][['Incident Zip', 'Descriptor', 'City']].('Incident Zip')
#                                                              ^
# SyntaxError: invalid syntax

# %%
requests[is_far][['Incident Zip', 'Descriptor', 'City']]
# Out:
#       Incident Zip         Descriptor         City
# 12102        77056      Debt Not Owed      HOUSTON
# 13450        70711   Contract Dispute      CLIFTON
# 29136        77092  False Advertising      HOUSTON
# 30939        55164         Harassment     ST. PAUL
# 44008        90010    Billing Dispute  LOS ANGELES
# 47048        23541         Harassment      NORFOLK
# 57636        92123         Harassment    SAN DIEGO
# 71001        92123    Billing Dispute    SAN DIEGO
# 71834        23502         Harassment      NORFOLK
# 80573        61702    Billing Dispute   BLOOMIGTON
# 85821        29616      Debt Not Owed   GREENVILLE
# 89304        35209         Harassment   BIRMINGHAM
# 94201        41042         Harassment     FLORENCE

# %%
#filter using city instead of zipcode 

requestsrequests['City'].str.upper().value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-82a17a2bc662> in <module>()
#       1 #filter using city instead of zipcode
#       2
# ----> 3 requestsrequests['City'].str.upper().value_counts()
#
# NameError: name 'requestsrequests' is not defined

# %%
#filter using city instead of zipcode 

requests['City'].str.upper().value_counts()
# Out:
# BROOKLYN                  31662
# NEW YORK                  22664
# BRONX                     18438
# STATEN ISLAND              4766
# JAMAICA                    2246
# FLUSHING                   1803
# ASTORIA                    1568
# RIDGEWOOD                  1073
# CORONA                      707
# OZONE PARK                  693
# LONG ISLAND CITY            678
# FAR ROCKAWAY                652
# ELMHURST                    647
# WOODSIDE                    609
# EAST ELMHURST               562
# QUEENS VILLAGE              549
# FOREST HILLS                541
# JACKSON HEIGHTS             541
# SOUTH RICHMOND HILL         521
# MASPETH                     473
# WOODHAVEN                   464
# FRESH MEADOWS               435
# SPRINGFIELD GARDENS         434
# BAYSIDE                     411
# SOUTH OZONE PARK            410
# RICHMOND HILL               404
# REGO PARK                   402
# MIDDLE VILLAGE              396
# SAINT ALBANS                387
# ...

# %%
#summary what was done to clean up the zip codes 

na_valuesna_value  = ['NO CLUE', 'N/A', '0']
requests = pd.read_csv('C:/Users/victory/Desktop/pandas-cookbook/data/311-service-requests.csv', 
                       na_values=na_values, 
                       dtype={'Incident Zip': str})

# %%
defdef  fix_zip_codesfix_zip_ (zips):
    # Truncate everything to length 5 
    zips = zips.str.slice(0, 5)
    
    # Set 00000 zip codes to nan
    zero_zips = zips == '00000'
    zips[zero_zips] = np.nan
    
    return zips
# Out:
#   File "<ipython-input-22-ba88d09224b4>", line 2
#     defdef  fix_zip_codesfix_zip_ (zips):
#                                 ^
# SyntaxError: invalid syntax

# %%
defdef  fix_zip_codes(zips):
    # Truncate everything to length 5 
    zips = zips.str.slice(0, 5)
    
    # Set 00000 zip codes to nan
    zero_zips = = '00000'
    zips[zero_zips] = np.nan
    
    return zips
# Out:
#   File "<ipython-input-23-0da35950f5f6>", line 2
#     defdef  fix_zip_codes(zips):
#                         ^
# SyntaxError: invalid syntax

# %%
def fix_zip_codes(zips):
     # Truncate everything to length 5 
    zips = zips.str.slice(0, 5)
    # Set 00000 zip codes to nan
    zero_zips = zips == '00000'
    zips[zero_zips] = np.nan
    return zips

# %%
requests['Incident Zip'] = fix_zip_codes(requests['Incident Zip'])

# %%
requestsrequests['Incident Zip'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-87fe5f437bd7> in <module>()
#       1
# ----> 2 requestsrequests['Incident Zip'].unique()
#
# NameError: name 'requestsrequests' is not defined

# %%
requests['Incident Zip'].unique()
# Out:
# array(['11432', '11378', '10032', '10023', '10027', '11372', '11419',
#        '11417', '10011', '11225', '11218', '10003', '10029', '10466',
#        '11219', '10025', '10310', '11236', nan, '10033', '11216', '10016',
#        '10305', '10312', '10026', '10309', '10036', '11433', '11235',
#        '11213', '11379', '11101', '10014', '11231', '11234', '10457',
#        '10459', '10465', '11207', '10002', '10034', '11233', '10453',
#        '10456', '10469', '11374', '11221', '11421', '11215', '10007',
#        '10019', '11205', '11418', '11369', '11249', '10005', '10009',
#        '11211', '11412', '10458', '11229', '10065', '10030', '11222',
#        '10024', '10013', '11420', '11365', '10012', '11214', '11212',
#        '10022', '11232', '11040', '11226', '10281', '11102', '11208',
#        '10001', '10472', '11414', '11223', '10040', '11220', '11373',
#        '11203', '11691', '11356', '10017', '10452', '10280', '11217',
# ...
