# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
pd.set_option('display.mpl_style', 'default')
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# <ipython-input-3-e13e29d3e7fa> in <module>()
# ----> 1 pd.set_option('display.mpl_style', 'default')
#
# ~\Anaconda3\lib\site-packages\pandas\core\config.py in __call__(self, *args, **kwds)
#     225
#     226     def __call__(self, *args, **kwds):
# --> 227         return self.__func__(*args, **kwds)
#     228
#     229     @property
#
# ~\Anaconda3\lib\site-packages\pandas\core\config.py in _set_option(*args, **kwargs)
#     117
#     118     for k, v in zip(args[::2], args[1::2]):
# --> 119         key = _get_single_key(k, silent)
#     120
#     121         o = _get_registered_option(key)
#
# ~\Anaconda3\lib\site-packages\pandas\core\config.py in _get_single_key(pat, silent)
#      81         if not silent:
#      82             _warn_if_deprecated(pat)
# ...

# %%
plt.show(block=True)

# %%
pd.set_option('display.mpl_style', 'default')
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# <ipython-input-5-e13e29d3e7fa> in <module>()
# ----> 1 pd.set_option('display.mpl_style', 'default')
#
# ~\Anaconda3\lib\site-packages\pandas\core\config.py in __call__(self, *args, **kwds)
#     225
#     226     def __call__(self, *args, **kwds):
# --> 227         return self.__func__(*args, **kwds)
#     228
#     229     @property
#
# ~\Anaconda3\lib\site-packages\pandas\core\config.py in _set_option(*args, **kwargs)
#     117
#     118     for k, v in zip(args[::2], args[1::2]):
# --> 119         key = _get_single_key(k, silent)
#     120
#     121         o = _get_registered_option(key)
#
# ~\Anaconda3\lib\site-packages\pandas\core\config.py in _get_single_key(pat, silent)
#      81         if not silent:
#      82             _warn_if_deprecated(pat)
# ...

# %%
matplotlib.style.use('ggplot')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3e838d222ef4> in <module>()
# ----> 1 matplotlib.style.use('ggplot')
#
# NameError: name 'matplotlib' is not defined

# %%
pd.style.use('ggplot')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-2d726e3b117c> in <module>()
# ----> 1 pd.style.use('ggplot')
#
# AttributeError: module 'pandas' has no attribute 'style'

# %%
plt.rcParams['figure.figsize'] = (15, 5)

# %%
broken_df = pd.read_csv('C:/Users/victory/Desktop/comptagevelo2012.csv')

# %%
# Look at the first 3 rows
broken_df[:3]
# Out:
#          Date Unnamed: 1  Rachel / Papineau  Berri1  Maisonneuve_2  \
# 0  01/01/2012      00:00                 16      35             51
# 1  02/01/2012      00:00                 43      83            153
# 2  03/01/2012      00:00                 58     135            248
#
#    Maisonneuve_1  Brébeuf  Parc  PierDup  CSC (Côte Sainte-Catherine)  \
# 0             38      5.0    26       10                            0
# 1             68     11.0    53        6                            1
# 2            104      2.0    89        3                            2
#
#    Pont_Jacques_Cartier
# 0                  27.0
# 1                  21.0
# 2                  15.0

# %%
fixed_df = pd.read_csv('C:/Users/victory/Desktop/comptagevelo2012.csv', sep=';', encoding='latin1', parse_dates=['Date'], dayfirst=True, index_col='Date')
fixed_df[:3]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-3b4f23cc754c> in <module>()
# ----> 1 fixed_df = pd.read_csv('C:/Users/victory/Desktop/comptagevelo2012.csv', sep=';', encoding='latin1', parse_dates=['Date'], dayfirst=True, index_col='Date')
#       2 fixed_df[:3]
#
# ...

# %%
df = pd.read_csv('C:/Users/victory/Desktop/comptagevelo2012.csv', sep=',', parse_dates={'datetime':[0, 1]}, index_col='datetime')

# %%
df.head()
# Out:
#             Rachel / Papineau  Berri1  Maisonneuve_2  Maisonneuve_1  Brébeuf  \
# datetime
# 2012-01-01                 16      35             51             38      5.0
# 2012-02-01                 43      83            153             68     11.0
# 2012-03-01                 58     135            248            104      2.0
# 2012-04-01                 61     144            318            116      2.0
# 2012-05-01                 95     197            330            124      6.0
#
#             Parc  PierDup  CSC (Côte Sainte-Catherine)  Pont_Jacques_Cartier
# datetime
# 2012-01-01    26       10                            0                  27.0
# 2012-02-01    53        6                            1                  21.0
# 2012-03-01    89        3                            2                  15.0
# 2012-04-01   111        8                            1                  19.0
# 2012-05-01    97       13                            2                  16.0

# %%
df['Berri 1']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Berri 1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-419ebafda559> in <module>()
# ----> 1 df['Berri 1']
#
# ...

# %%
fixed_df['Berri 1']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-e4367e1e475f> in <module>()
# ----> 1 fixed_df['Berri 1']
#
# NameError: name 'fixed_df' is not defined

# %%
df['Berri 1']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Berri 1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-419ebafda559> in <module>()
# ----> 1 df['Berri 1']
#
# ...

# %%
url = 'http://donnees.ville.montreal.qc.ca/dataset/f170fecc-18db-44bc-b4fe-5b0b6d2c7297/resource/d54cec49-349e-47af-b152-7740056d7311/download/comptagevelo2012.csv'

# %%
df = pd.read_csv(url, sep=',', parse_dates={'datetime':[0, 1]}, index_col='datetime')

# %%
df.head()
# Out:
#             Rachel / Papineau  Berri1  Maisonneuve_2  Maisonneuve_1  Brébeuf  \
# datetime
# 2012-01-01                 16      35             51             38      5.0
# 2012-02-01                 43      83            153             68     11.0
# 2012-03-01                 58     135            248            104      2.0
# 2012-04-01                 61     144            318            116      2.0
# 2012-05-01                 95     197            330            124      6.0
#
#             Parc  PierDup  CSC (Côte Sainte-Catherine)  Pont_Jacques_Cartier
# datetime
# 2012-01-01    26       10                            0                  27.0
# 2012-02-01    53        6                            1                  21.0
# 2012-03-01    89        3                            2                  15.0
# 2012-04-01   111        8                            1                  19.0
# 2012-05-01    97       13                            2                  16.0

# %%
df['Berri 1']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Berri 1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-419ebafda559> in <module>()
# ----> 1 df['Berri 1']
#
# ...

# %%
df['Berri 1'].plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Berri 1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-3d62aec3f19b> in <module>()
# ----> 1 df['Berri 1'].plot()
#
# ...

# %%
fixed_df = pd.read_csv('C:/Users/victory/Desktop/comptagevelo2012.csv', sep=';', encoding='latin1', parse_dates=['Date'], dayfirst=True, index_col='Date')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-52d75415c794> in <module>()
# ----> 1 fixed_df = pd.read_csv('C:/Users/victory/Desktop/comptagevelo2012.csv', sep=';', encoding='latin1', parse_dates=['Date'], dayfirst=True, index_col='Date')
#
# ...

# %%
fixed_df = pd.read_csv('C:/Users/victory/Desktop/comptagevelo2012.csv', sep=',', parse_dates={'datetime':[0, 1]}, index_col='datetime')
fixed_df[:3]
# Out:
#             Rachel / Papineau  Berri1  Maisonneuve_2  Maisonneuve_1  Brébeuf  \
# datetime
# 2012-01-01                 16      35             51             38      5.0
# 2012-02-01                 43      83            153             68     11.0
# 2012-03-01                 58     135            248            104      2.0
#
#             Parc  PierDup  CSC (Côte Sainte-Catherine)  Pont_Jacques_Cartier
# datetime
# 2012-01-01    26       10                            0                  27.0
# 2012-02-01    53        6                            1                  21.0
# 2012-03-01    89        3                            2                  15.0

# %%
fixed_df['Berri 1']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Berri 1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-e4367e1e475f> in <module>()
# ----> 1 fixed_df['Berri 1']
#
# ...

# %%
fixed_df['Berri1']
# Out:
# datetime
# 2012-01-01      35
# 2012-02-01      83
# 2012-03-01     135
# 2012-04-01     144
# 2012-05-01     197
# 2012-06-01     146
# 2012-07-01      98
# 2012-08-01      95
# 2012-09-01     244
# 2012-10-01     397
# 2012-11-01     273
# 2012-12-01     157
# 2012-01-13      75
# 2012-01-14      32
# 2012-01-15      54
# 2012-01-16     168
# 2012-01-17     155
# 2012-01-18     139
# 2012-01-19     191
# 2012-01-20     161
# 2012-01-21      53
# 2012-01-22      71
# 2012-01-23     210
# 2012-01-24     299
# 2012-01-25     334
# 2012-01-26     306
# 2012-01-27      91
# 2012-01-28      80
# 2012-01-29      87
# 2012-01-30     219
#               ...
# 2012-02-12     324
# 2012-03-12    1286
# 2012-04-12    1264
# 2012-05-12    1204
# 2012-06-12    1252
# 2012-07-12    1151
# 2012-08-12     382
# 2012-09-12     427
# 2012-10-12     245
# 2012-11-12     517
# 2012-12-12     598
# 2012-12-13     655
# 2012-12-14     738
# 2012-12-15     335
# 2012-12-16     177
# 2012-12-17     236
# ...

# %%
fixed_dffixed_d ['Berri1'].plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-4124f3177c5e> in <module>()
#       1
# ----> 2 fixed_dffixed_d ['Berri1'].plot()
#
# NameError: name 'fixed_dffixed_d' is not defined

# %%
fixed_df['Berri1'].plot()

# %%
fixed_df.plot(figsize=(15, 10))

# %%
df = pd.read_csv('C:/Users/victory/Desktop/comptagevelo2012.csv', sep=';', encoding='latin1', parse_dates=['Date'], dayfirst=True, index_col='Date')
df['Berri1'].plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-515e0053baa5> in <module>()
# ----> 1 df = pd.read_csv('C:/Users/victory/Desktop/comptagevelo2012.csv', sep=';', encoding='latin1', parse_dates=['Date'], dayfirst=True, index_col='Date')
#       2 df['Berri1'].plot()
#
# ...

# %%
df = pd.read_csv('C:/Users/victory/Desktop/comptagevelo2012.csv', sep=',', parse_dates={'datetime':[0, 1]}, index_col='datetime')
df['Berri1'].plot()
