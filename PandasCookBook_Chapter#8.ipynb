# %%
import pandas as pd

# %%
# Read it, and remove the last row
popcon = pd.read_csv('C:/Users/victory/Desktop/pandas-cookbook/data/popularity-contest', sep=' ', )[:-1]
popcon.columns = ['atime', 'ctime', 'package-name', 'mru-program', 'tag']

# %%
popcon[:55]
# Out:
#          atime       ctime          package-name  \
# 0   1387295797  1367633260             perl-base
# 1   1387295796  1354370480                 login
# 2   1387295743  1354341275            libtalloc2
# 3   1387295743  1387224204          libwbclient0
# 4   1387295742  1354341253           libselinux1
# 5   1387295742  1354341275            libstdc++6
# 6   1387295740  1387224202        libpam-winbind
# 7   1387295740  1354341253        libpam-modules
# 8   1387295740  1354341253   libpam-ck-connector
# 9   1387295740  1354341253            libpam-cap
# 10  1387295740  1354341253              libpam0g
# 11  1387295740  1368154184  libpam-gnome-keyring
# 12  1387295738  1354341253               libgcc1
# 13  1387295737  1383017433                 libc6
# 14  1387295737  1354341253               libcap2
# 15  1387295737  1354341257      libck-connector0
# 16  1387295737  1372944527           libdbus-1-3
# 17  1387295733  1385396738       fingerprint-gui
# ...

# %%
#convert to datetimes 
popcon['atime'] = popcon['atime'].astype(int)
popcon['ctime'] = popcon['ctime'].astype(int)

# %%
popcon['atime''atime'] = pd.to_datetime(popcon['atime'], unit='s')

# %%
popcon['ctime'] = pd.to_datetime(popcon['ctime'], unit='s')

# %%
# return the datatype 
popcon['atime'].dtype
# Out:
# dtype('int32')

# %%
popcon[:5]
# Out:
#         atime               ctime  package-name  \
# 0  1387295797 2013-05-04 02:07:40     perl-base
# 1  1387295796 2012-12-01 14:01:20         login
# 2  1387295743 2012-12-01 05:54:35    libtalloc2
# 3  1387295743 2013-12-16 20:03:24  libwbclient0
# 4  1387295742 2012-12-01 05:54:13   libselinux1
#
#                                     mru-program             tag  \
# 0                                 /usr/bin/perl             NaN
# 1                                       /bin/su             NaN
# 2  /usr/lib/x86_64-linux-gnu/libtalloc.so.2.0.7             NaN
# 3    /usr/lib/x86_64-linux-gnu/libwbclient.so.0  <RECENT-CTIME>
# 4         /lib/x86_64-linux-gnu/libselinux.so.1             NaN
#
#            atimeatime
# 0 2013-12-17 15:56:37
# 1 2013-12-17 15:56:36
# 2 2013-12-17 15:55:43
# 3 2013-12-17 15:55:43
# 4 2013-12-17 15:55:42

# %%
# get rid of timestamp zero
popcon = popcon[popcon['atimeatime'] > '1970-01-01']

# %%
#get rows where package name doesn't contain lib
nonlibraries = popcon[~popcon['package-name'].str.contains('lib')]

# %%
popcon[~popcon['package-name'].str.contains('lib')].sort_values('ctime',ascending=False)[:10]
# Out:
#           atime               ctime               package-name  \
# 57   1387256139 2013-12-17 04:55:42                        ddd
# 450  1387224200 2013-12-16 20:05:13                     nodejs
# 454  1387224200 2013-12-16 20:05:04  switchboard-plug-keyboard
# 445  1387224200 2013-12-16 20:05:04      thunderbird-locale-en
# 396  1387224507 2013-12-16 20:05:03            software-center
# 449  1387224200 2013-12-16 20:05:00           samba-common-bin
# 397  1387224505 2013-12-16 20:04:59      postgresql-client-9.1
# 398  1387224503 2013-12-16 20:04:58             postgresql-9.1
# 452  1387224200 2013-12-16 20:04:55                   php5-dev
# 440  1387224200 2013-12-16 20:04:54                   php-pear
#
#                                            mru-program             tag  \
# 57                                        /usr/bin/ddd  <RECENT-CTIME>
# 450                                       /usr/bin/npm  <RECENT-CTIME>
# ...
